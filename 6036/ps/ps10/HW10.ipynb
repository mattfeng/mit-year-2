# %%
import mdp10
import hw10
# Out:
# /Users/mattfeng/envs/deep/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
hw10.test_learn_play(iters=1000000, tabular=True, batch=False)
# Out:
# score (0, 6.0)
# score (100000, 23.0)
# score (200000, 27.9)
# score (300000, 37.4)
# score (400000, 70.0)
# score (500000, 72.1)
# score (600000, 90.1)
# score (700000, 84.3)
# score (800000, 89.3)
# score (900000, 100.0)
# String to upload (incude quotes): "..."
# Reward 100
# Reward 100
# Reward 100
# Reward 88
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 18
# Reward 100

# %%
hw10.test_learn_play(iters=200, tabular=True, batch=True)
# Out:
# score (0, 6.0)
# score (20, 34.0)
# score (40, 35.0)
# score (60, 54.5)
# score (80, 66.0)
# score (100, 62.6)
# score (120, 86.3)
# score (140, 100.0)
# score (160, 95.1)
# score (180, 75.0)
# String to upload (incude quotes): ""
# Reward 100
# Reward 100
# Reward 75
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100

# %%
import mdp10
import hw10

hw10.test_learn_play(iters=10, tabular=False, batch=False)
# Out:
# /Users/mattfeng/envs/deep/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# num states: 3889
# score (0, 100)
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 1.1284
# score (1, 100)
# Epoch 1/1
# 1/1 [==============================] - 0s 219ms/step - loss: 1.8986
# score (2, 100)
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7839
# score (3, 100)
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9612
# score (4, 100)
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9243
# score (5, 100)
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7493
# score (6, 100)
# Epoch 1/1
# ...

# %%
hw10.test_learn_play(iters=10, tabular=False, batch=True)
# Out:
# num states: 3889
# score (0, 100)
# Epoch 1/10
# 26/26 [==============================] - 0s 13ms/step - loss: 0.9542
# Epoch 2/10
# 26/26 [==============================] - 0s 57us/step - loss: 0.7593
# Epoch 3/10
# 26/26 [==============================] - 0s 59us/step - loss: 0.5687
# Epoch 4/10
# 26/26 [==============================] - 0s 87us/step - loss: 0.3899
# Epoch 5/10
# 26/26 [==============================] - 0s 67us/step - loss: 0.2569
# Epoch 6/10
# 26/26 [==============================] - 0s 70us/step - loss: 0.1661
# Epoch 7/10
# 26/26 [==============================] - 0s 99us/step - loss: 0.1153
# Epoch 8/10
# 26/26 [==============================] - 0s 82us/step - loss: 0.0949
# Epoch 9/10
# 26/26 [==============================] - 0s 67us/step - loss: 0.0978
# Epoch 10/10
# 26/26 [==============================] - 0s 87us/step - loss: 0.1137
# Epoch 1/10
# 22/22 [==============================] - 0s 16ms/step - loss: 1.2842
# Epoch 2/10
# ...
