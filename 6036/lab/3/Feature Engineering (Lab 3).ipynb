# %%
import pandas as pd

# %%
autompg = pd.read_csv("./data/auto-mpg.tsv", sep="\t")

# %%
autompg
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0     -1          8         304.0         193    4732          18.5
# 1     -1          8         307.0         200    4376          15.0
# 2     -1          8         360.0         215    4615          14.0
# 3     -1          8         318.0         210    4382          13.5
# 4     -1          8         350.0         180    3664          11.0
# 5     -1          8         400.0         150    4997          14.0
# 6     -1          8         429.0         208    4633          11.0
# 7     -1          8         350.0         160    4456          13.5
# 8     -1          8         350.0         180    4499          12.5
# 9     -1          8         383.0         180    4955          11.5
# 10    -1          8         400.0         167    4906          12.5
# 11    -1          8         429.0         198    4952          11.5
# 12    -1          8         455.0         225    4951          11.0
# ...

# %%
reviews = pd.read_csv("./data/reviews.tsv", sep="\t")

# %%
reviews
# Out:
#       sentiment   productId          userId  \
# 0            -1  B001E5E1KA  A3BPS5Z69S82MV
# 1            -1  B001CPQPXI  A1WCT6YAYIWLRV
# 2            -1  B00654I0XE   A45NFCAENHRMD
# 3            -1  B000FBM480  A1FEP94TP15RG0
# 4            -1  B002KB2CMG  A31CQ4G2QFVMDE
# 5             1  B004XNZLEK  A1P8P6QKO7GX9U
# 6             1  B005ZBZM52  A285C2SQLVSF2B
# 7             1  B001ONPMN2  A25SXOKA0K8V67
# 8            -1  B004G1WFH0   APLFMSCR4VQEI
# 9             1  B000RIAE9C  A325NNFLKRUZQ3
# 10           -1  B000MBM19K   A2WOKQ831GDZU
# 11            1  B000GDB096  A1HZQJ5KWRW27H
# 12            1  B003VXFK44  A2OZPL96MVDILY
# 13           -1  B002VTE84C  A15QVA30H0JRG0
# 14            1  B004U7QXMS  A18Y2GKMS5MIS8
# 15           -1  B003T0W5LK  A1KOT8QF046CCQ
# 16            1  B003QNJYXM  A3EFN73FY0AW32
# 17           -1  B000QSON4K  A1DGJ84K1GYJXF
# 18           -1  B008K9TQPS  A3R9P241ZX3NNY
# 19            1  B00390T5JA  A2TJG4N8LNJW23
# ...
